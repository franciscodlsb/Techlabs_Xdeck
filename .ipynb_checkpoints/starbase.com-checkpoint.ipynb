# %%
import pandas as pd
import requests
import csv
from bs4 import BeautifulSoup

# %%
# Extract urls from website
def get_company_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    all_as = soup.find_all("a")
    links = []
    
    for a in all_as:
        link = a.get("href")
        if (link is not None and '/organization/' in link 
            and not '/organization/new/' in link):
            links.append(link)
            
    return links

# %%
# Extract the info from a company url
def get_company_info(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Name, logo and teaser
    title_card = soup.find('div', 'flex-grow-1 mx-lg-4')
    startup_name = title_card.h1.get('data-name')
    logo = title_card.h1.get('data-icon')
    teaser = title_card.find('div', 'sb-teaser').text.strip()
    
    # Body info
    body_card = soup.find('ul', 'unformated row justify-content-start mb-0')
    info_cards = body_card.find_all('li')
    startup_info = []; labels_info = []

    for count, info in enumerate(info_cards):
        labels_info.append(info.text.strip().split(':')[0])
        if count != 9: #10th item is links to social media
            info_piece = info.text.strip()
            # text cleaning
            if '\n ' in info_piece:
                info_piece = info_piece.split('\n ')[1]
            else:
                info_piece = info_piece.split(': ')[1]

            if info_piece[0] == ' ':
                info_piece = info_piece[1::]   
        else: #social media
            media_links = []
            for media in info.find_all('a'):
                media_links.append(media.get('href'))
            info_piece = media_links

        startup_info.append(info_piece)

    # About info
    about_company = soup.find('div', {'class':'sb-card mb-4'}, id='company').p.text
    
    # Team info
    # Get names
    member_names = soup.find_all('span',{'class':'name'})
    names = [];
    for name in member_names:
        names.append(name.text)
    # Get labels
    member_labels = soup.find_all('span',{'class':'label'})
    labels = [];
    for label in member_labels:
        labels.append(label.text)  
    team_members = dict(zip(names, labels))
    
    # Join extracted data
    info_data = [startup_name] + [logo] + [teaser] + startup_info + [about_company] + [team_members]
    info_labels = ['Name'] + ['Logo'] + ['Teaser'] + labels_info + ['About'] + ['Members']
    
    company_data = dict(zip(info_labels, info_data))
    
    return company_data

# %%
url = 'https://www.startbase.com/startups/?listOptions%5Bcompany-startup%5D=%7B%22version%22%3A1.3%2C%22sort%22%3A%22company.startbase_score%22%2C%22sortDirection%22%3A%22desc%22%2C%22display%22%3A%22small%22%2C%22itemsPerPage%22%3A21%2C%22page%22%3A1%2C%22userLocation%22%3Anull%2C%22filters%22%3A%7B%7D%7D'

links = get_company_links(url)
data = []

for i, link in enumerate(links):
    data.append(get_company_info(link))
        
dataframe = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-10b3b8f7ac50> in <module>()
#       5
#       6 for i, link in enumerate(links):
# ----> 7     data.append(get_company_info(link))
#       8
#       9 dataframe = pd.DataFrame(data)
#
# <ipython-input-63-0349af0d3b3e> in get_company_info(url)
#      23                 info_piece = info_piece.split('\n ')[1]
#      24             else:
# ---> 25                 info_piece = info_piece.split(': ')[1]
#      26
#      27             if info_piece[0] == ' ':
#
# IndexError: list index out of range

# %%
dataframe = pd.DataFrame(data)
dataframe.head(10)
# Out:
#                 Name                                               Logo  \
# 0   Mädchenflohmarkt  https://cdn.startbase.com/images/company/m-dch...
# 1         Nia Health  https://cdn.startbase.com/images/company/nia-h...
# 2    Swarm Logistics  https://cdn.startbase.com/images/company/swarm...
# 3              Recup  https://cdn.startbase.com/images/company/recup...
# 4      Rock my Sleep  https://cdn.startbase.com/images/company/rock-...
# 5           ParkHere  https://cdn.startbase.com/images/55e1d72d8041e...
# 6       MyHelpBuddy   https://cdn.startbase.com/images/company/myhel...
# 7  Green Convenience  https://cdn.startbase.com/images/25eca7e696e8b...
# 8         Heartucate  https://cdn.startbase.com/images/company/heart...
# 9          ViveLaCar  https://cdn.startbase.com/images/970698203834f...
#
#                                               Teaser  \
# 0  Mädchenflohmarkt develops an online market for...
# 1  Nia - the eczema app - tailoring medical treat...
# 2  Swarm Logistics GmbH is a Deep-Tech software t...
# 3  Brands of reCup GmbH. Innovative and sustainab...
# 4  Toys for children that can play music and acco...
# 5  Smart High-Tech Solutions for Digital Parking ...
# 6  A marketplace for expats to book locals for an...
# 7  Location based software in the area of predict...
# 8  Creating learning quests with Augmented Realit...
# 9  Mobility platform that allows drivers to conve...
#
#                              Sector  Company Stage       Business Model  \
# 0                          Textiles   Growth Stage             Platform
# 1         Life Science & Healthcare     Seed Stage                 SaaS
# 2      Industrial & Basic Materials  Startup Stage                 SaaS
# 3           Nutrition & Consumables  Startup Stage     Sale of Services
# 4       Media, Arts & Entertainment     Seed Stage  Retail / E-Commerce
# 5  Automotive, Logistics & Mobility  Startup Stage                 SaaS
# 6                             Other     Seed Stage             Platform
# 7             IT and Communications     Seed Stage                 SaaS
# 8                         Education     Seed Stage                 SaaS
# 9  Automotive, Logistics & Mobility  Startup Stage             Platform
#
#   Customer Focus Founding Year          Team Size Handelsregister  \
# 0            B2C          2012  101-250 Employees           Found
# 1            B2C          2019     1-10 Employees           Found
# 2            B2B          2018                n/a           Found
# 3            B2B          2016    11-50 Employees           Found
# 4            B2C          2020     1-10 Employees           Found
# 5            B2B          2015    11-50 Employees           Found
# 6            B2C          2019     1-10 Employees           Found
# 7            B2B          2020     1-10 Employees           Found
# 8            B2C          2020     1-10 Employees           Found
# 9          B2B2C          2019    11-50 Employees           Found
#
#      Headquarter       Official Website  \
# 0  Stuttgart, DE   maedchenflohmarkt.de
# 1     Berlin, DE          nia-health.de
# 2  Stuttgart, DE     swarmlogistics.net
# 3    München, DE               recup.de
# 4  Stuttgart, DE        rockmysleep.com
# 5    München, DE           park-here.eu
# 6     Berlin, DE        myhelpbuddy.com
# 7    Maintal, DE  green-convenience.com
# 8    Leipzig, DE          heartucate.eu
# 9  Stuttgart, DE          vivelacar.com
#
#                                      On Social Media  \
# 0  [https://www.instagram.com/maedchenflohmarkt/,...
# 1  [https://www.instagram.com/nia.neurodermitis.h...
# 2  [https://twitter.com/swarmlogistics, https://w...
# 3  [https://twitter.com/recup2go, https://www.lin...
# 4  [https://www.instagram.com/rockmysleep/, https...
# 5  [https://twitter.com/ParkHere_muc, https://www...
# 6  [https://twitter.com/buddy_help, https://www.l...
# 7  [https://www.youtube.com/channel/UC8FaA-oTNSFV...
# 8  [https://www.instagram.com/heartucate/, https:...
# 9  [https://www.instagram.com/vivelacar_autoabo/,...
#
#                           Legal Entity  \
# 0                Mädchenflohmarkt GmbH
# 1                      Nia Health GmbH
# 2                 Swarm Logistics GmbH
# 3                           Recup GmbH
# 4                   Rock my Sleep GmbH
# 5                        ParkHere GmbH
# 6  MyHelpBuddy UG (haftungsbeschränkt)
# 7                 Green Convenience UG
# 8                        Heartucate UG
# 9                       ViveLaCar GmbH
#
#                                                About  \
# 0  Mädchenflohmarkt ist der Marktplatz für hochwe...
# 1  Nia Health develops and markets a service plat...
# 2  Swarm Logistics is a Deep-Tech software techno...
# 3  Pro Stunde werden in Deutschland ca. 320.000 E...
# 4  Schnauze voll von LaLeLu? Frischgebackenen Elt...
# 5  Die Städte wachsen, und die daraus resultieren...
# 6  MyHelpBuddy is a marketplace for expats and in...
# 7  We provide advanced Analytics to ensure succes...
# 8  HEARTUCATE means: learning together in new dim...
# 9  The ViveLaCar car subscription closes the gap ...
#
#                                              Members
# 0                              {'Peter Ambrozy': ''}
# 1  {'Dr. Reem Alneebari': 'Founder & CMO', 'Tobia...
# 2                              {'Damir Dulovic': ''}
# 3  {'Stefanie Ullrich': '', 'Florian Pachaly': 'F...
# 4                    {'Michael Heimrich': 'Founder'}
# 5                                 {'Felix Bopf': ''}
# 6  {'Christina Papke': 'Co-Founder & COO', 'Aravi...
# 7  {'Benjamin Dauth, MBA': 'Co-Founder and CEO', ...
# 8                     {'Franziska Weser': 'Founder'}
# 9  {'Florine von Caprivi': 'CRO', 'Mathias Albert...

# %%
links
# Out:
# ['https://www.startbase.com/organization/m-dchenflohmarkt/',
#  'https://www.startbase.com/organization/nia-health/',
#  'https://www.startbase.com/organization/swarm-logistics/',
#  'https://www.startbase.com/organization/recup/',
#  'https://www.startbase.com/organization/rock-my-sleep/',
#  'https://www.startbase.com/organization/parkhere/',
#  'https://www.startbase.com/organization/myhelpbuddy/',
#  'https://www.startbase.com/organization/green-convenience/',
#  'https://www.startbase.com/organization/heartucate/',
#  'https://www.startbase.com/organization/vivelacar/',
#  'https://www.startbase.com/organization/debtvision/',
#  'https://www.startbase.com/organization/noor-medical/',
#  'https://www.startbase.com/organization/blinkist/',
#  'https://www.startbase.com/organization/spacegoats/',
#  'https://www.startbase.com/organization/chumai-consulting-solutions/',
#  'https://www.startbase.com/organization/oohlemon/',
#  'https://www.startbase.com/organization/w-o-wohnrechner-online/',
#  'https://www.startbase.com/organization/creditshelf/',
#  'https://www.startbase.com/organization/kuchentratsch/',
#  'https://www.startbase.com/organization/smapone/',
#  'https://www.startbase.com/organization/ostellus/',
#  'https://www.startbase.com/organization/chocri/',
#  'https://www.startbase.com/organization/carefuel/',
#  'https://www.startbase.com/organization/poacher-sports/',
#  'https://www.startbase.com/organization/buckleandseam/',
#  'https://www.startbase.com/organization/bitterpower-gmbh/',
#  'https://www.startbase.com/organization/lean-koala/',
#  'https://www.startbase.com/organization/the-chainless-deepva/',
#  'https://www.startbase.com/organization/pioniergeist-gmbh/',
#  'https://www.startbase.com/organization/roamlike/',
#  'https://www.startbase.com/organization/my-blossom/',
#  'https://www.startbase.com/organization/epilot-mobility-dein-flexibles-mobilitaetsbudget/',
#  'https://www.startbase.com/organization/edyoucated/',
#  'https://www.startbase.com/organization/agilegravity/',
#  'https://www.startbase.com/organization/olmatic/',
#  'https://www.startbase.com/organization/landopay/',
#  'https://www.startbase.com/organization/mergeflow/',
#  'https://www.startbase.com/organization/tramedix/',
#  'https://www.startbase.com/organization/weltenmacher-gmbh/',
#  'https://www.startbase.com/organization/groupify/',
#  'https://www.startbase.com/organization/vencortex/',
#  'https://www.startbase.com/organization/capmatcher-com/',
#  'https://www.startbase.com/organization/lofino/',
#  'https://www.startbase.com/organization/gamebuddy-gmbh/',
#  'https://www.startbase.com/organization/agrilution-0e132ed3/',
#  'https://www.startbase.com/organization/hedge21/',
#  'https://www.startbase.com/organization/vilisto-gmbh/',
#  'https://www.startbase.com/organization/r3dt-gmbh-meet-your-reality/',
#  'https://www.startbase.com/organization/peakboard-gmbh/',
#  'https://www.startbase.com/organization/gapcharge/',
#  'https://www.startbase.com/organization/medengine/',
#  'https://www.startbase.com/organization/bookingbuddy/',
#  'https://www.startbase.com/organization/discoeat/',
#  'https://www.startbase.com/organization/spoontainable/',
#  'https://www.startbase.com/organization/51nodes/',
#  'https://www.startbase.com/organization/deutschfuchs-gesellschaft-fur-digitalen-unterricht/',
#  'https://www.startbase.com/organization/aucobo-gmbh/',
#  'https://www.startbase.com/organization/mysupply-expertist-vertriebs-gmbh/',
#  'https://www.startbase.com/organization/iwos/',
#  'https://www.startbase.com/organization/urmo/',
#  'https://www.startbase.com/organization/blue-excellence/',
#  'https://www.startbase.com/organization/meadow-robotics-gmbh/',
#  'https://www.startbase.com/organization/terra-vegane/',
#  'https://www.startbase.com/organization/n26/',
#  'https://www.startbase.com/organization/myshoefitter/',
#  'https://www.startbase.com/organization/air-up/',
#  'https://www.startbase.com/organization/unisphere-gmbh/',
#  'https://www.startbase.com/organization/zalando/',
#  'https://www.startbase.com/organization/targomo/',
#  'https://www.startbase.com/organization/scaling-spaces/',
#  'https://www.startbase.com/organization/sitemotion/',
#  'https://www.startbase.com/organization/eventbuddy/',
#  'https://www.startbase.com/organization/packwise/',
#  'https://www.startbase.com/organization/cherrydeck/',
#  'https://www.startbase.com/organization/koena-tec/',
#  'https://www.startbase.com/organization/aervideo-gmbh/',
#  'https://www.startbase.com/organization/ahwoo-gmbh/',
#  'https://www.startbase.com/organization/meshparts/',
#  'https://www.startbase.com/organization/patavinus/',
#  'https://www.startbase.com/organization/equil/',
#  'https://www.startbase.com/organization/kamedi-gmbh/',
#  'https://www.startbase.com/organization/localyzer-gmbh/',
#  'https://www.startbase.com/organization/idee-gmbh/',
#  'https://www.startbase.com/organization/the-female-company/',
#  'https://www.startbase.com/organization/laserhub/',
#  'https://www.startbase.com/organization/epap/',
#  'https://www.startbase.com/organization/spindiag-gmbh/',
#  'https://www.startbase.com/organization/freelance-pages-ag/',
#  'https://www.startbase.com/organization/vialytics-gmbh/',
#  'https://www.startbase.com/organization/sallab/',
#  'https://www.startbase.com/organization/pokeshot/',
#  'https://www.startbase.com/organization/motionminers-gmbh/',
#  'https://www.startbase.com/organization/plentyleads-gmbh/',
#  'https://www.startbase.com/organization/pixolus/',
#  'https://www.startbase.com/organization/ixpoint-informationssysteme-gmbh/',
#  'https://www.startbase.com/organization/jolt-energy-gmbh/',
#  'https://www.startbase.com/organization/xu-exponential-university-group/',
#  'https://www.startbase.com/organization/seawater-cubes/',
#  'https://www.startbase.com/organization/contory-the-content-factory/',
#  'https://www.startbase.com/organization/hublock-io/',
#  'https://www.startbase.com/organization/the-female-company/',
#  'https://www.startbase.com/organization/creditshelf/',
#  'https://www.startbase.com/organization/high-tech-gr-nderfonds-management-gmbh/',
#  'https://www.startbase.com/organization/vialytics/',
#  'https://www.startbase.com/organization/laserhub/',
#  'https://www.startbase.com/organization/targomo/',
#  'https://www.startbase.com/organization/amorelie/',
#  'https://www.startbase.com/organization/forto/',
#  'https://www.startbase.com/organization/motor-ai/']
